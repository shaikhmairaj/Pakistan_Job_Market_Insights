# %% [markdown]
# ### Load Data

# %%
import pandas as pd

# %%
df =pd.read_csv("Data/raw/rozee_jobs.csv")
df.head()
# Out:
#                                      Title                      Salary  \
# 0                Order Fulfillment Manager  PKR. 30,000 - 60,000/Month
# 1  Enterprise Business Development Manager                         NaN
# 2                             Video Editor  PKR. 30,000 - 30,000/Month
# 3               Branch in Charge (Patokki)  PKR. 60,000 - 60,000/Month
# 4                     Senior PHP Developer                         NaN
#
#               Job Type                                       Job Location  \
# 0  Full Time/Permanent  Lahore,\n                                     ...
# 1  Full Time/Permanent  Lahore,\n                                     ...
# 2  Full Time/Permanent  Karachi,\n                                    ...
# 3  Full Time/Permanent  Patoki,\n                                     ...
# 4  Full Time/Permanent  Lahore,\n                                     ...
#
#   Functional Area              Career Level Apply Before Minimum Experience  \
# 0          Retail  Experienced Professional     3-Jan-25            2 Years
# 1             NaN                       NaN    19-Jan-25            3 Years
# 2             NaN                       NaN    19-Jan-25             1 Year
# 3             NaN                       NaN    19-Jan-25            3 Years
# 4             NaN                       NaN    19-Jan-25            3 Years
#
#       Minimum Education         Gender  Age  \
# 0  Intermediate/A-Level           Male  NaN
# 1                   NaN  No Preference  NaN
# 2                   NaN  No Preference  NaN
# 3                   NaN  No Preference  NaN
# 4                   NaN  No Preference  NaN
#
#                                               Skills
# 0  Team Building, Order Tracking, Order Processin...
# 1  Relationship Building, Sales Acumen, Market Re...
# 2                                       Video Editor
# 3  Customer Service, Problem Solving, Communicati...
# 4  PHP, MySQL, Javascript, Laravel, HTML, CSS, Gi...

# %% [markdown]
# ### Rename columns

# %%
df = df.rename(columns={
    "Title": "job_title",
    "Salary": "salary",
    "Job Type": "employment_type",
    "Job Location": "city",
    "Functional Area": "domain",
    "Career Level": "career_level",
    "Apply Before": "apply_deadline",
    "Minimum Experience": "min_experience",
    "Minimum Education": "min_education",
    "Gender": "gender",
    "Age": "age",
    "Skills": "skills"
})

# %% [markdown]
# ### Clean experience

# %%
pip install numpy pyodbc sqlalchemy
# Out:
# Requirement already satisfied: numpy in c:\users\mairaj\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pyodbc in c:\users\mairaj\anaconda3\lib\site-packages (5.1.0)
# Requirement already satisfied: sqlalchemy in c:\users\mairaj\anaconda3\lib\site-packages (1.4.54)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\mairaj\anaconda3\lib\site-packages (from sqlalchemy) (3.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
print(df.columns)
# Out:
# Index(['job_title', 'salary', 'employment_type', 'city', 'domain',
#        'career_level', 'apply_deadline', 'min_experience', 'min_education',
#        'gender', 'age', 'skills'],
#       dtype='object')

# %%
import re

def clean_exp(x):
    if pd.isna(x):
        return None

    x = str(x).lower()

    if "fresh" in x or "less" in x:
        return 0

    numbers = re.findall(r'\d+', x)

    if len(numbers) == 0:
        return None
    elif len(numbers) == 1:
        return int(numbers[0])
    else:
        # agar range ho (e.g. 3-5 years) to average le lo
        return int(sum(map(int, numbers)) / len(numbers))

# %%
df["min_experience"] = df["min_experience"].apply(clean_exp)

# %%
df["min_experience"].value_counts().head(10)
# Out:
# min_experience
# 1.0     165
# 2.0     154
# 3.0     140
# 0.0     140
# 5.0      69
# 4.0      36
# 10.0     15
# 8.0       8
# 7.0       6
# 6.0       6
# Name: count, dtype: int64

# %% [markdown]
# ### Experience level

# %%
def exp_level(x):
    if x is None:
        return None
    if x <= 1:
        return "Junior"
    elif x <= 4:
        return "Mid"
    else:
        return "Senior"

df["experience_level"] = df["min_experience"].apply(exp_level)

# %% [markdown]
# ### Clean salary

# %%
import re

def clean_salary(val):
    if pd.isna(val):
        return pd.Series([None, None])
    nums = re.findall(r'\d+', str(val))
    if len(nums) >= 2:
        return pd.Series([int(nums[0]), int(nums[1])])
    return pd.Series([None, None])

df[["salary_min", "salary_max"]] = df["salary"].apply(clean_salary)

# %% [markdown]
# ### Clean City Colunm

# %%
df["city"] = df["city"].str.title().str.strip()

# %% [markdown]
# ### Save cleaned file

# %%
df.to_csv("Data/cleaned/jobs_cleaned.csv", index=False)
print("Saved successfully")
# Out:
# Saved successfully

# %%
df.head()
# Out:
#                                  job_title                      salary  \
# 0                Order Fulfillment Manager  PKR. 30,000 - 60,000/Month
# 1  Enterprise Business Development Manager                         NaN
# 2                             Video Editor  PKR. 30,000 - 30,000/Month
# 3               Branch in Charge (Patokki)  PKR. 60,000 - 60,000/Month
# 4                     Senior PHP Developer                         NaN
#
#        employment_type                                               city  \
# 0  Full Time/Permanent  Lahore,\n                                     ...
# 1  Full Time/Permanent  Lahore,\n                                     ...
# 2  Full Time/Permanent  Karachi,\n                                    ...
# 3  Full Time/Permanent  Patoki,\n                                     ...
# 4  Full Time/Permanent  Lahore,\n                                     ...
#
#    domain              career_level apply_deadline  min_experience  \
# 0  Retail  Experienced Professional       3-Jan-25             2.0
# 1     NaN                       NaN      19-Jan-25             3.0
# 2     NaN                       NaN      19-Jan-25             1.0
# 3     NaN                       NaN      19-Jan-25             3.0
# 4     NaN                       NaN      19-Jan-25             3.0
#
#           min_education         gender  age  \
# 0  Intermediate/A-Level           Male  NaN
# 1                   NaN  No Preference  NaN
# 2                   NaN  No Preference  NaN
# 3                   NaN  No Preference  NaN
# 4                   NaN  No Preference  NaN
#
#                                               skills experience_level  \
# 0  Team Building, Order Tracking, Order Processin...              Mid
# 1  Relationship Building, Sales Acumen, Market Re...              Mid
# 2                                       Video Editor           Junior
# 3  Customer Service, Problem Solving, Communicati...              Mid
# 4  PHP, MySQL, Javascript, Laravel, HTML, CSS, Gi...              Mid
#
#    salary_min  salary_max
# 0        30.0         0.0
# 1         NaN         NaN
# 2        30.0         0.0
# 3        60.0         0.0
# 4         NaN         NaN

# %%
df[["salary_min", "salary_max"]].head()
# Out:
#    salary_min  salary_max
# 0        30.0         0.0
# 1         NaN         NaN
# 2        30.0         0.0
# 3        60.0         0.0
# 4         NaN         NaN

# %%
print(df.salary_min)
# Out:
# 0       30.0
# 1        NaN
# 2       30.0
# 3       60.0
# 4        NaN
#         ...
# 1054    40.0
# 1055    50.0
# 1056    40.0
# 1057     NaN
# 1058    30.0
# Name: salary_min, Length: 1059, dtype: float64
